# %%
import pandas as pd
import xarray as xr

# %%
df_baseline = pd.read_excel('../AvoidedEmissionsRateBaseline.xlsx',
                            sheet_name = 'HourlyAvoidedEmissionsRate')
df_ecr = pd.read_excel('../AvoidedEmissionsRateEarlyCoalRetirement.xlsx',
                            sheet_name = 'HourlyAvoidedEmissionsRate')

# %%
df_bl_hourly = df_baseline[['Report_Hour','Emissions Rate Estimate']]
df_ecr_hourly = df_ecr[['Report_Hour','Emissions Rate Estimate']]

# %%
df_bl_hourlymean = df_bl_hourly.groupby('Report_Hour').mean()
df_ecr_hourlymean = df_ecr_hourly.groupby('Report_Hour').mean()

# %%
df_bl_hourlymean.insert(1,'ECR',df_ecr_hourlymean['Emissions Rate Estimate'],True)

# %%
df = df_bl_hourlymean
df.rename(columns={"Emissions Rate Estimate": "Baseline", "ECR": "Early Coal Retirement"})
# Out:
#              Baseline  Early Coal Retirement
# Report_Hour
# 1            0.870693               0.623164
# 2            0.877812               0.642336
# 3            0.889447               0.661387
# 4            0.905546               0.678457
# 5            0.903432               0.652986
# 6            0.902680               0.636088
# 7            0.724216               0.573594
# 8            0.625128               0.472856
# 9            0.505466               0.363618
# 10           0.485714               0.350934
# 11           0.491875               0.320150
# 12           0.508172               0.326815
# 13           0.511329               0.329154
# 14           0.515683               0.321275
# 15           0.521420               0.330015
# 16           0.529992               0.320087
# 17           0.546548               0.337733
# 18           0.543454               0.361055
# 19           0.568429               0.410700
# 20           0.662656               0.477872
# 21           0.747596               0.536600
# 22           0.812098               0.261006
# 23           0.796911               0.494698
# 24           0.821903               0.466288

# %%
xr_data = xr.Dataset.from_dataframe(df)

# %%
xr_data.to_netcdf('../../../processed_data/data_bl_ecr.nc')
